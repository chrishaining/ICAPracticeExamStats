# %% [markdown]
# # ICA Certificate Statistics

# %% [markdown]
# This notebook contains statistics on the time it took me to answer each question in the sample multiple choice assessment for the [ICA Specialist Certificate in Money Laundering Risk in New Technology](https://www.int-comp.org/programme/?title=ICA-Specialist-Certificate-in-Money-Laundering-Risk-in-New-Technology&mkt_tok=eyJpIjoiTkRRME9USm1PRGt5WlRreCIsInQiOiJTb09jT3hXOWV1TUkyWlI4bWtDcEZqZnZKajFFWmhLbnZsZlFXR0dwdHRGVVpyVXFWcVIxWUV0SWczZU5XRDE1b09TSFQxNmNYQ3B1eDVObis3dzk5RzNnak5XXC8wUDZheFpXOENFZFhJMFFGalJBNkk2VVwvSGxwaWFlendRMGptIn0%3D#Courseformat).

# %%
import pandas as pd
import numpy as np

second_test_times = []
question1 = {'time':13, 'pass': True}
question2 = {'time': 9, 'pass': True}
question3 = {'time': 28, 'pass': True}
question4 = {'time': 11, 'pass': True}
question5 = {'time': 5, 'pass': True}
question6 = {'time': 15, 'pass': True}
question7 = {'time': 10, 'pass': True}
question8 = {'time': 17, 'pass': True}
question9 = {'time': 13, 'pass': True}
question10 = {'time': 9, 'pass': True}
question11 = {'time': 21, 'pass': True}
question12 = {'time': 26, 'pass': True}
question13 = {'time': 10, 'pass': True}
question14 = {'time': 30, 'pass': True}
question15 = {'time': 19, 'pass': True}
question16 = {'time': 19, 'pass': True}
question17 = {'time': 15, 'pass': True}
question18 = {'time': 36, 'pass': True}
question19 = {'time': 13, 'pass': True}
question20 = {'time': 10, 'pass': True}
question21 = {'time': 20, 'pass': True}
question22 = {'time': 13, 'pass': True}
question23 = {'time': 33, 'pass': True}
question24 = {'time': 63, 'pass': True}
question25 = {'time': 20, 'pass': True}

second_test_times.append(question1)
second_test_times.append(question2)
second_test_times.append(question3)
second_test_times.append(question4)
second_test_times.append(question5)
second_test_times.append(question6)
second_test_times.append(question7)
second_test_times.append(question8)
second_test_times.append(question9)
second_test_times.append(question10)
second_test_times.append(question11)
second_test_times.append(question12)
second_test_times.append(question13)
second_test_times.append(question14)
second_test_times.append(question15)
second_test_times.append(question16)
second_test_times.append(question17)
second_test_times.append(question18)
second_test_times.append(question19)
second_test_times.append(question20)
second_test_times.append(question21)
second_test_times.append(question22)
second_test_times.append(question23)
second_test_times.append(question24)
second_test_times.append(question25)

data=np.array(second_test_times)

def change_pass_text(arr):
    for item in data:
        if item['pass'] == True:
            item['pass'] = 'Pass'
        else: 
            item['pass'] = 'Fail'
    return data

changed_text_data = change_pass_text(data)
parsed_data = [(item['time'], item['pass']) for item in changed_text_data]
# print(parsed_data)

# df = pd.DataFrame(data, index = ['Cochice', 'Pima', 'Santa Cruz', 'Maricopa', 'Yuma'])

question_numbers = list(range(1, 26)) 

table = pd.DataFrame(data=np.array(parsed_data), index=question_numbers, columns=['Time(seconds)', 'Pass or Fail?'])
# table.style
# table.style.set_table_styles([{'selector':'','props':[('border','4px solid #7a7')]}])



def colour_code(val):
    if val == 'Pass':
        color = 'green'
    else: 
        color = 'black'
    return 'color: %s' % color

colour_coded_table = table.style.applymap(colour_code)
colour_coded_table
# Out:
# <style  type="text/css" >
#     #T_96d0576c_6394_11ea_a4ba_a4d18ceefbaerow0_col0 {
#             color:  black;
#         }    #T_96d0576c_6394_11ea_a4ba_a4d18ceefbaerow0_col1 {
#             color:  green;
#         }    #T_96d0576c_6394_11ea_a4ba_a4d18ceefbaerow1_col0 {
#             color:  black;
#         }    #T_96d0576c_6394_11ea_a4ba_a4d18ceefbaerow1_col1 {
#             color:  green;
#         }    #T_96d0576c_6394_11ea_a4ba_a4d18ceefbaerow2_col0 {
#             color:  black;
#         }    #T_96d0576c_6394_11ea_a4ba_a4d18ceefbaerow2_col1 {
#             color:  green;
#         }    #T_96d0576c_6394_11ea_a4ba_a4d18ceefbaerow3_col0 {
#             color:  black;
#         }    #T_96d0576c_6394_11ea_a4ba_a4d18ceefbaerow3_col1 {
#             color:  green;
#         }    #T_96d0576c_6394_11ea_a4ba_a4d18ceefbaerow4_col0 {
#             color:  black;
#         }    #T_96d0576c_6394_11ea_a4ba_a4d18ceefbaerow4_col1 {
#             color:  green;
# ...

# %% [markdown]
# ## Results
#
# Test 1 took 17 minutes. My estimate of the score prior to taking the test was 40-80%. After taking the test this changed to 30-60%. The actual score was 52% (13/25).
# After taking the test, I reviewed my answers.
#
# Prior to taking the test, I reviewed the answers.
# Test 2 took 14 minutes 47 seconds in total. My estimate of the score prior to taking the test was 60-90%. After takiing the test this changed to 60-80%. The actual score was 100% (25/25).
